# %%
import tweepy
import requests
import json

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **To get the ID of any twitter user using their username. I used mine as an example.**

# %%
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAHY0qwEAAAAA1mK6X0I6PRaNDl7ur1yBOcKVp00%3D0Dy4avIiPSBv86gJosabgHddFqIlp28ykKM7gZ00bIaLtjNlDi'


def create_url():
    # Specify the usernames that you want to lookup below
    # You can enter up to 100 comma-separated values.
    usernames = "usernames=_stan_leigh"
    
    user_fields = "user.fields=description,created_at"
    # User fields are adjustable, options include:
    # created_at, description, entities, id, location, name,
    # pinned_tweet_id, profile_image_url, protected,
    # public_metrics, url, username, verified, and withheld
    url = "https://api.twitter.com/2/users/by?{}&{}".format(usernames, user_fields)
    return url


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2UserLookupPython"
    return r


def connect_to_endpoint(url):
    response = requests.request("GET", url, auth=bearer_oauth,)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main():
    url = create_url()
    json_response = connect_to_endpoint(url)
    print(json.dumps(json_response, indent=4, sort_keys=True))


if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "created_at": "2018-09-12T14:23:26.000Z",
#             "description": "",
#             "id": "1039882181106126848",
#             "name": "Stan Lee",
#             "username": "_stan_leigh"
#         }
#     ]
# }

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **list of tweets liked by a user. You provide a userID here. I used userID 12 which is for Jack, the former CEO of Twitter**

# %%
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAHY0qwEAAAAA1mK6X0I6PRaNDl7ur1yBOcKVp00%3D0Dy4avIiPSBv86gJosabgHddFqIlp28ykKM7gZ00bIaLtjNlDi'


def create_url():
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    tweet_fields = "tweet.fields=lang,author_id"
    # Be sure to replace your-user-id with your own user ID or one of an authenticating user
    # You can find a user ID by using the user lookup endpoint
    id = "12"
    # You can adjust ids to include a single Tweets.
    # Or you can add to up to 100 comma-separated IDs
    url = "https://api.twitter.com/2/users/{}/liked_tweets".format(id)
    return url, tweet_fields


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2LikedTweetsPython"
    return r


def connect_to_endpoint(url, tweet_fields):
    response = requests.request(
        "GET", url, auth=bearer_oauth, params=tweet_fields)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main():
    url, tweet_fields = create_url()
    json_response = connect_to_endpoint(url, tweet_fields)
    print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
main()
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "3111553475",
#             "edit_history_tweet_ids": [
#                 "1727864042671206876"
#             ],
#             "id": "1727864042671206876",
#             "lang": "en",
#             "text": "So GRATEFUL for all of my *Twitter family. \ud83e\udd70"
#         },
#         {
#             "author_id": "16205746",
#             "edit_history_tweet_ids": [
#                 "1726778325597569350"
#             ],
#             "id": "1726778325597569350",
#             "lang": "en",
#             "text": "Good news, you can now pay a monthly fee for your bed so your sleep data can be used for social marketing campaigns! https://t.co/ntcT6DvmTU"
#         },
#         {
#             "author_id": "18989355",
#             "edit_history_tweet_ids": [
#                 "1702167635092222409"
#             ],
#             "id": "1702167635092222409",
#             "lang": "en",
# ...

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **list of users that liked a tweet. Here, you need the ID of the tweet in question. It can usually be gotten from the tweet URL.**

# %%
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAHY0qwEAAAAA1mK6X0I6PRaNDl7ur1yBOcKVp00%3D0Dy4avIiPSBv86gJosabgHddFqIlp28ykKM7gZ00bIaLtjNlDi'


def create_url():
    # User fields are adjustable, options include:
    # created_at, description, entities, id, location, name,
    # pinned_tweet_id, profile_image_url, protected,
    # public_metrics, url, username, verified, and withheld
    user_fields = "user.fields=created_at,description"
    # You can replace the ID given with the Tweet ID you wish to like.
    # You can find an ID by using the Tweet lookup endpoint
    id = "1354143047324299264"
    # You can adjust ids to include a single Tweets.
    # Or you can add to up to 100 comma-separated IDs
    url = "https://api.twitter.com/2/tweets/{}/liking_users".format(id)
    return url, user_fields


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2LikingUsersPython"
    return r


def connect_to_endpoint(url, user_fields):
    response = requests.request("GET", url, auth=bearer_oauth, params=user_fields)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main():
    url, tweet_fields = create_url()
    json_response = connect_to_endpoint(url, tweet_fields)
    print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
main()
# Out:
# 200
# {
#     "data": [
#         {
#             "created_at": "2023-07-31T03:19:39.000Z",
#             "description": "",
#             "id": "1685852664356114432",
#             "name": "Kasandra Weiner",
#             "username": "KasandrW"
#         },
#         {
#             "created_at": "2023-07-24T23:06:45.000Z",
#             "description": "",
#             "id": "1683614694597332992",
#             "name": "Karri Selva",
#             "username": "karri_se"
#         },
#         {
#             "created_at": "2022-06-11T19:20:16.000Z",
#             "description": "\ud83c\udff4\u200d\u2620\ufe0fAI \ud83c\udde8\ud83c\udde6 e/acc \ud83e\uddd1\ud83c\udffb\u200d\ud83d\udcbbOptimistic \ud83d\ude01 Founder & BUILDING THE FUTURE @ BEDI. A Good Human, Honest ! Brave ! Love my Dad & Mom \u2764\ufe0f This is my only acc. No DMs\ud83d\udeab",
#             "id": "1535703318705623040",
#             "name": "BEDI ANAKIN \ud83c\udf0e\u2665\ufe0f",
# ...

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ****list of users that retweeted a tweet. Here, you need the ID of the tweet in question. It can usually be gotten from the tweet URL.****

# %%
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAHY0qwEAAAAA1mK6X0I6PRaNDl7ur1yBOcKVp00%3D0Dy4avIiPSBv86gJosabgHddFqIlp28ykKM7gZ00bIaLtjNlDi'


def create_url():
    # User fields are adjustable, options include:
    # created_at, description, entities, id, location, name,
    # pinned_tweet_id, profile_image_url, protected,
    # public_metrics, url, username, verified, and withheld
    user_fields = "user.fields=created_at,description"
    # You can replace the ID given with the Tweet ID you wish to lookup Retweeting users for
    # You can find an ID by using the Tweet lookup endpoint
    id = "1704480823578075623"
    # You can adjust ids to include a single Tweets.
    # Or you can add to up to 100 comma-separated IDs
    url = "https://api.twitter.com/2/tweets/{}/retweeted_by".format(id)
    return url, user_fields


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RetweetedByPython"
    return r


def connect_to_endpoint(url, user_fields):
    response = requests.request("GET", url, auth=bearer_oauth, params=user_fields)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main():
    url, user_fields = create_url()
    json_response = connect_to_endpoint(url, user_fields)
    print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
main()
# Out:
# 200
# {
#     "data": [
#         {
#             "created_at": "2022-07-06T05:37:57.000Z",
#             "description": "Economist||Data Analyst",
#             "id": "1544556196841115651",
#             "name": "Arewa Analyst",
#             "username": "Musa_A_Jnr"
#         },
#         {
#             "created_at": "2013-12-24T17:02:25.000Z",
#             "description": "Data Analyst, Business Development Manager, Founder Swift Hub Ng.",
#             "id": "2241905315",
#             "name": "Dansarki",
#             "username": "DansarkiInspire"
#         },
#         {
#             "created_at": "2019-08-04T08:55:21.000Z",
#             "description": "Critical thinker, Knowledge Enthusiast, Internet Wizard, #ArsenalFan, #CreditRiskAnalyst Goal getter, Mathematical... Child of God.",
#             "id": "1157938058165137413",
#             "name": "$AMM\u00a5LLIONAIR\u00a3 \u2122",
#             "username": "sammyllionaire1"
#         },
#         {
# ...

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **For the follower and following task. See the image below.**

# %% [markdown]
# <img src="Twitter Change Logs.png" alt="Alternative text" />

# %% [markdown]
# -------------------------------------------------------------------------------------------------
